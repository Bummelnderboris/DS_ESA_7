# %% [markdown]
# With the given task "Load the Grid_Disruption_00_14_standardized - Grid_Disruption_00_14_standardized.csv Dataset from Kaggle: 15 YEARS OF POWER OUTAGES. Where are errors here? How would you clean this file?", I decided to not use trifacta.com and instead write an own receipe to analyse for improving the understanding of why is which step when important.

# %%
#import our stuff and have a look at the dataframe 
import pandas as pd
import matplotlib as plt
import numpy as np


df = pd.read_csv ("datasets_22520_28884_Grid_Disruption_00_14_standardized_Grid_Disruption_00_14_standardized.csv")

#drop duplicates if there are some
df = df.drop_duplicates()

df.head(20)
# Out:
#                  Event Description  Year Date Event Began Time Event Began  \
# 0   Severe Weather - Thunderstorms  2014        6/30/2014          8:00 PM
# 1   Severe Weather - Thunderstorms  2014        6/30/2014         11:20 PM
# 2   Severe Weather - Thunderstorms  2014        6/30/2014          5:55 PM
# 3     Fuel Supply Emergency - Coal  2014        6/27/2014          1:21 PM
# 4      Physical Attack - Vandalism  2014        6/24/2014          2:54 PM
# 5      Physical Attack - Vandalism  2014        6/19/2014          8:47 AM
# 6      Physical Attack - Vandalism  2014        6/18/2014          9:52 AM
# 7   Severe Weather - Thunderstorms  2014        6/18/2014          5:00 PM
# 8   Severe Weather - Thunderstorms  2014        6/15/2014         12:00 AM
# 9        Suspected Physical Attack  2014        6/12/2014          9:10 AM
# 10     Physical Attack - Vandalism  2014        6/11/2014          4:00 PM
# 11       Suspected Physical Attack  2014        6/11/2014          9:30 AM
# 12  Severe Weather - Thunderstorms  2014        6/10/2014          9:50 PM
# 13     Electrical System Islanding  2014         6/9/2014         11:07 AM
# 14  Severe Weather - Thunderstorms  2014         6/7/2014         11:00 PM
# 15    Fuel Supply Emergency - Coal  2014         6/6/2014          1:00 PM
# 16  Severe Weather - Thunderstorms  2014         6/5/2014          3:00 AM
# 17  Severe Weather - Thunderstorms  2014         6/5/2014          1:06 PM
# 18     Electrical System Islanding  2014         6/3/2014          3:32 PM
# 19     Physical Attack - Vandalism  2014         6/3/2014          1:38 AM
#
#    Date of Restoration Time of Restoration  \
# 0             7/2/2014             6:30 PM
# 1             7/1/2014             5:00 PM
# 2             7/1/2014             2:53 AM
# 3              Unknown             Unknown
# 4            6/24/2014             2:55 PM
# 5            6/19/2014             8:48 AM
# 6            6/18/2014             7:00 PM
# 7            6/20/2014             3:00 PM
# 8            6/15/2014             1:00 AM
# 9            6/12/2014             9:11 AM
# 10           6/11/2014             4:30 PM
# 11           6/11/2014             9:31 AM
# 12           6/11/2014             2:30 PM
# 13            6/9/2014            11:30 AM
# 14            6/8/2014             5:30 AM
# 15             Unknown             Unknown
# 16            6/7/2014            11:45 PM
# 17            6/5/2014             1:07 PM
# 18            6/3/2014             3:59 PM
# 19            6/3/2014             1:43 AM
#
#                                            Respondent  \
# 0                            Exelon Corporation/ComEd
# 1             Northern Indiana Public Service Company
# 2                                         We Energies
# 3                                         We Energies
# 4                          Tennessee Valley Authority
# 5                          Tennessee Valley Authority
# 6   Public Utility District No.1 of Snohomish Coun...
# 7                                   Detroit Edison Co
# 8                                         Xcel Energy
# 9                        Luminant Energy Company, LLC
# 10                      South Mississippi El Pwr Assn
# 11                              Tucson Electric Power
# 12                            American Electric Power
# 13                                   Peak Reliability
# 14                                   Southern Company
# 15                       Luminant Energy Company, LLC
# 16               Memphis Light Gas and Water Division
# 17                         Tennessee Valley Authority
# 18                                   Peak Reliability
# 19                     Lower Colorado River Authority
#
#                Geographic Areas NERC Region Demand Loss (MW)  \
# 0                      Illinois         RFC          Unknown
# 1         North Central Indiana         RFC          Unknown
# 2          Southeast  Wisconsin         MRO              424
# 3                     Wisconsin         MRO          Unknown
# 4          Nashville, Tennessee        SERC          Unknown
# 5          Nashville, Tennessee        SERC          Unknown
# 6                    Washington        WECC          Unknown
# 7            Southeast Michigan         RFC          Unknown
# 8             Central Minnesota         MRO          Unknown
# 9       Somervell County, Texas       ERCOT          Unknown
# 10         Southern Mississippi        SERC              NaN
# 11             Nogales, Arizona        WECC              NaN
# 12                West Virginia         RFC          Unknown
# 13              Alberta, Canada        WECC          Unknown
# 14  North and Central , Alabama        SERC              217
# 15                        Texas       ERCOT          Unknown
# 16     Shelby County, Tennessee        SERC              494
# 17               West Tennessee        SERC          Unknown
# 18              Alberta, Canada        WECC              338
# 19                        Texas       ERCOT          Unknown
#
#    Number of Customers Affected                          Tags
# 0                       420,000  severe weather, thunderstorm
# 1                       127,000  severe weather, thunderstorm
# 2                       120,000  severe weather, thunderstorm
# 3                       Unknown   fuel supply emergency, coal
# 4                       Unknown           vandalism, physical
# 5                       Unknown           vandalism, physical
# 6                       Unknown           vandalism, physical
# 7                       138,802  severe weather, thunderstorm
# 8                        55,951  severe weather, thunderstorm
# 9                       Unknown           vandalism, physical
# 10                          NaN           vandalism, physical
# 11                          NaN           vandalism, physical
# 12                       66,383  severe weather, thunderstorm
# 13                      Unknown                     islanding
# 14                       65,000  severe weather, thunderstorm
# 15                      Unknown   fuel supply emergency, coal
# 16                       38,500  severe weather, thunderstorm
# 17                       56,475  severe weather, thunderstorm
# 18                          NaN                     islanding
# 19                      Unknown           vandalism, physical

# %% [markdown]
# So: Where are errors here? How would you clean this file?
#
# It is observable that there are aswell Unknown as NaN Values given. Because of the consistence of this pattern it is assumed we need this disticntion, so changing the dtype to a date for columns like "Date Event Began" won't be a usefull strategy. This circumstance makes it a bit difficult to plot or analyse data because of non consistent data types in one column, so we have them stored as objects. Assuming we need to keep the information if a value is unknown, there are three different possibilities. We could (1) create a new column for the values with matching dtype. (2) We could include the solution in a query, for example with try and except. (3) We could asign nonsense values within the matching type to Unknown values.
#
# The first possibility would create a lot of redundant data in the same data frame and the third one might be inconstitent on longterm effects so I suggest to use the second strategy and handle unknown values within the query, or create a whole new date frame with cleaned values. (We will do it in the end of this exercise)
#
# We also need to know how many "Unknown" objects are listed in the dataset.

# %%
#before doing so lets have a quick look at the data types
df.dtypes

#as expected we have a lot of objects because of the different contents in one column
# Out:
# Event Description               object
# Year                             int64
# Date Event Began                object
# Time Event Began                object
# Date of Restoration             object
# Time of Restoration             object
# Respondent                      object
# Geographic Areas                object
# NERC Region                     object
# Demand Loss (MW)                object
# Number of Customers Affected    object
# Tags                            object
# dtype: object

# %%
#Now lets distinguish between empty and unknown

#empty
all_v = np.product(df.shape)
miss_v = df.isnull().sum()


per_v = miss_v/all_v*100
print("List of empty values in %:")
per_v
# Out:
# % of empty values
# Event Description               0.000000
# Year                            0.000000
# Date Event Began                0.000000
# Time Event Began                0.045400
# Date of Restoration             0.070621
# Time of Restoration             0.100888
# Respondent                      0.000000
# Geographic Areas                0.005044
# NERC Region                     0.010089
# Demand Loss (MW)                2.007667
# Number of Customers Affected    1.079500
# Tags                            0.005044
# dtype: float64

# %%
#unknown
unk_v = df == "Unknown"

un_co_v = unk_v.sum()

print("List of unkown values in %:")
un_co_v / all_v*100
# Out:
# List of unkown values in %:
# Event Description               0.000000
# Year                            0.000000
# Date Event Began                0.000000
# Time Event Began                0.000000
# Date of Restoration             0.055488
# Time of Restoration             0.055488
# Respondent                      0.000000
# Geographic Areas                0.040355
# NERC Region                     0.000000
# Demand Loss (MW)                1.044189
# Number of Customers Affected    0.731437
# Tags                            0.000000
# dtype: float64

# %%
#To avoid missunderstandings in future we will clear all missing seels and replace them with a blankspace.
df = df.fillna("")
df.head(20)
# Out:
#                  Event Description  Year Date Event Began Time Event Began  \
# 0   Severe Weather - Thunderstorms  2014        6/30/2014          8:00 PM
# 1   Severe Weather - Thunderstorms  2014        6/30/2014         11:20 PM
# 2   Severe Weather - Thunderstorms  2014        6/30/2014          5:55 PM
# 3     Fuel Supply Emergency - Coal  2014        6/27/2014          1:21 PM
# 4      Physical Attack - Vandalism  2014        6/24/2014          2:54 PM
# 5      Physical Attack - Vandalism  2014        6/19/2014          8:47 AM
# 6      Physical Attack - Vandalism  2014        6/18/2014          9:52 AM
# 7   Severe Weather - Thunderstorms  2014        6/18/2014          5:00 PM
# 8   Severe Weather - Thunderstorms  2014        6/15/2014         12:00 AM
# 9        Suspected Physical Attack  2014        6/12/2014          9:10 AM
# 10     Physical Attack - Vandalism  2014        6/11/2014          4:00 PM
# 11       Suspected Physical Attack  2014        6/11/2014          9:30 AM
# 12  Severe Weather - Thunderstorms  2014        6/10/2014          9:50 PM
# 13     Electrical System Islanding  2014         6/9/2014         11:07 AM
# 14  Severe Weather - Thunderstorms  2014         6/7/2014         11:00 PM
# 15    Fuel Supply Emergency - Coal  2014         6/6/2014          1:00 PM
# 16  Severe Weather - Thunderstorms  2014         6/5/2014          3:00 AM
# 17  Severe Weather - Thunderstorms  2014         6/5/2014          1:06 PM
# 18     Electrical System Islanding  2014         6/3/2014          3:32 PM
# 19     Physical Attack - Vandalism  2014         6/3/2014          1:38 AM
#
#    Date of Restoration Time of Restoration  \
# 0             7/2/2014             6:30 PM
# 1             7/1/2014             5:00 PM
# 2             7/1/2014             2:53 AM
# 3              Unknown             Unknown
# 4            6/24/2014             2:55 PM
# 5            6/19/2014             8:48 AM
# 6            6/18/2014             7:00 PM
# 7            6/20/2014             3:00 PM
# 8            6/15/2014             1:00 AM
# 9            6/12/2014             9:11 AM
# 10           6/11/2014             4:30 PM
# 11           6/11/2014             9:31 AM
# 12           6/11/2014             2:30 PM
# 13            6/9/2014            11:30 AM
# 14            6/8/2014             5:30 AM
# 15             Unknown             Unknown
# 16            6/7/2014            11:45 PM
# 17            6/5/2014             1:07 PM
# 18            6/3/2014             3:59 PM
# 19            6/3/2014             1:43 AM
#
#                                            Respondent  \
# 0                            Exelon Corporation/ComEd
# 1             Northern Indiana Public Service Company
# 2                                         We Energies
# 3                                         We Energies
# 4                          Tennessee Valley Authority
# 5                          Tennessee Valley Authority
# 6   Public Utility District No.1 of Snohomish Coun...
# 7                                   Detroit Edison Co
# 8                                         Xcel Energy
# 9                        Luminant Energy Company, LLC
# 10                      South Mississippi El Pwr Assn
# 11                              Tucson Electric Power
# 12                            American Electric Power
# 13                                   Peak Reliability
# 14                                   Southern Company
# 15                       Luminant Energy Company, LLC
# 16               Memphis Light Gas and Water Division
# 17                         Tennessee Valley Authority
# 18                                   Peak Reliability
# 19                     Lower Colorado River Authority
#
#                Geographic Areas NERC Region Demand Loss (MW)  \
# 0                      Illinois         RFC          Unknown
# 1         North Central Indiana         RFC          Unknown
# 2          Southeast  Wisconsin         MRO              424
# 3                     Wisconsin         MRO          Unknown
# 4          Nashville, Tennessee        SERC          Unknown
# 5          Nashville, Tennessee        SERC          Unknown
# 6                    Washington        WECC          Unknown
# 7            Southeast Michigan         RFC          Unknown
# 8             Central Minnesota         MRO          Unknown
# 9       Somervell County, Texas       ERCOT          Unknown
# 10         Southern Mississippi        SERC
# 11             Nogales, Arizona        WECC
# 12                West Virginia         RFC          Unknown
# 13              Alberta, Canada        WECC          Unknown
# 14  North and Central , Alabama        SERC              217
# 15                        Texas       ERCOT          Unknown
# 16     Shelby County, Tennessee        SERC              494
# 17               West Tennessee        SERC          Unknown
# 18              Alberta, Canada        WECC              338
# 19                        Texas       ERCOT          Unknown
#
#    Number of Customers Affected                          Tags
# 0                       420,000  severe weather, thunderstorm
# 1                       127,000  severe weather, thunderstorm
# 2                       120,000  severe weather, thunderstorm
# 3                       Unknown   fuel supply emergency, coal
# 4                       Unknown           vandalism, physical
# 5                       Unknown           vandalism, physical
# 6                       Unknown           vandalism, physical
# 7                       138,802  severe weather, thunderstorm
# 8                        55,951  severe weather, thunderstorm
# 9                       Unknown           vandalism, physical
# 10                                        vandalism, physical
# 11                                        vandalism, physical
# 12                       66,383  severe weather, thunderstorm
# 13                      Unknown                     islanding
# 14                       65,000  severe weather, thunderstorm
# 15                      Unknown   fuel supply emergency, coal
# 16                       38,500  severe weather, thunderstorm
# 17                       56,475  severe weather, thunderstorm
# 18                                                  islanding
# 19                      Unknown           vandalism, physical

# %%
#doublecheck if we filled all missing values
miss_v = df.isnull().sum()

per_v = miss_v/all_v*100
print("List of empty values in %:")
per_v
# Out:
# List of empty values in %:
# Event Description               0.0
# Year                            0.0
# Date Event Began                0.0
# Time Event Began                0.0
# Date of Restoration             0.0
# Time of Restoration             0.0
# Respondent                      0.0
# Geographic Areas                0.0
# NERC Region                     0.0
# Demand Loss (MW)                0.0
# Number of Customers Affected    0.0
# Tags                            0.0
# dtype: float64

# %%
#Now we got a dataframe with the disticntion, if a value is unknown or not given.
df
# Out:
#                    Event Description  Year Date Event Began Time Event Began  \
# 0     Severe Weather - Thunderstorms  2014        6/30/2014          8:00 PM
# 1     Severe Weather - Thunderstorms  2014        6/30/2014         11:20 PM
# 2     Severe Weather - Thunderstorms  2014        6/30/2014          5:55 PM
# 3       Fuel Supply Emergency - Coal  2014        6/27/2014          1:21 PM
# 4        Physical Attack - Vandalism  2014        6/24/2014          2:54 PM
# ...                              ...   ...              ...              ...
# 1647          Transmission Line Loss  2000        3/18/2000        4:00 p.m.
# 1648                       Vandalism  2000        3/14/2000        9:06 p.m.
# 1649                       Ice Storm  2000        1/29/2000       10:00 p.m.
# 1650                       Ice Storm  2000        1/24/2000        7:00 p.m.
# 1651                       Ice Storm  2000        1/23/2000        8:00 a.m.
#
#      Date of Restoration Time of Restoration  \
# 0               7/2/2014             6:30 PM
# 1               7/1/2014             5:00 PM
# 2               7/1/2014             2:53 AM
# 3                Unknown             Unknown
# 4              6/24/2014             2:55 PM
# ...                  ...                 ...
# 1647           3/18/2000          5:10:00 PM
# 1648
# 1649            2/3/2000         12:00:00 PM
# 1650
# 1651           1/28/2000         12:00:00 PM
#
#                                    Respondent  \
# 0                    Exelon Corporation/ComEd
# 1     Northern Indiana Public Service Company
# 2                                 We Energies
# 3                                 We Energies
# 4                  Tennessee Valley Authority
# ...                                       ...
# 1647                        El Paso Elec. Co.
# 1648                           Alliant Energy
# 1649                           Duke Power Co.
# 1650                   Carolina Power & Light
# 1651                           Duke Power Co.
#
#                               Geographic Areas NERC Region Demand Loss (MW)  \
# 0                                     Illinois         RFC          Unknown
# 1                        North Central Indiana         RFC          Unknown
# 2                         Southeast  Wisconsin         MRO              424
# 3                                    Wisconsin         MRO          Unknown
# 4                         Nashville, Tennessee        SERC          Unknown
# ...                                        ...         ...              ...
# 1647                                     Texas        MAIN              400
# 1648                                     Maine        MAIN
# 1649                            South Carolina        SERC              300
# 1650  North Carolina & Northern South Carolina        SERC              960
# 1651                            South Carolina        SERC              450
#
#      Number of Customers Affected                          Tags
# 0                         420,000  severe weather, thunderstorm
# 1                         127,000  severe weather, thunderstorm
# 2                         120,000  severe weather, thunderstorm
# 3                         Unknown   fuel supply emergency, coal
# 4                         Unknown           vandalism, physical
# ...                           ...                           ...
# 1647                      100,000     transmission interruption
# 1648                                                  vandalism
# 1649                       81,000  severe weather, winter storm
# 1650                      173,000  severe weather, winter storm
# 1651                      133,000  severe weather, winter storm
#
# [1652 rows x 12 columns]

# %%
# Out:
# type

# %%
#Let's also prepare a dataframe with less information but matching data type
df1 = pd.read_csv ("datasets_22520_28884_Grid_Disruption_00_14_standardized_Grid_Disruption_00_14_standardized.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e9bf6cce0202> in <module>
#       1 #Let's also prepare a dataframe with less information but matching data type
# ----> 2 df1 = pd.read_csv ("datasets_22520_28884_Grid_Disruption_00_14_standardized_Grid_Disruption_00_14_standardized.csv")
#
# NameError: name 'pd' is not defined
